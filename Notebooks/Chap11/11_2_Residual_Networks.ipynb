# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(
    args, path="./mnist1d_data.pkl", download=False, regenerate=False
)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data["y"])))
print("Examples in test set: {}".format(len(data["y_test"])))
print("Length of each example: {}".format(data["x"].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data["x"].transpose()
train_data_y = data["y"]
val_data_x = data["x_test"].transpose()
val_data_y = data["y_test"]
# Print out sizes
print(
    "Train data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((train_data_x.shape[1], train_data_x.shape[0]))
)
print(
    "Validation data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((val_data_x.shape[1], val_data_x.shape[0]))
)
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class


class ResidualNetwork(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(ResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, output_size)
        print(
            "Initialized MLPBase model with {} parameters".format(self.count_params())
        )

    def count_params(self):
        return sum([p.view(-1).shape[0] for p in self.parameters()])

    # TODO -- Add residual connections to this model
    # The order of operations within each block should similar to figure 11.5b
    # ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
    # Replace this function
    def forward(self, x):
        h1 = self.linear1(x)
        h2 = h1 + self.linear2(h1.relu())
        h3 = h2 + self.linear3(h2.relu())
        return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)

# %%
# Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype("float32"))
y_train = torch.tensor(train_data_y.astype("long"))
x_val = torch.tensor(val_data_x.transpose().astype("float32"))
y_val = torch.tensor(val_data_y.astype("long"))

# load the data into a class that creates the batches
data_loader = DataLoader(
    TensorDataset(x_train, y_train),
    batch_size=100,
    shuffle=True,
    worker_init_fn=np.random.seed(1),
)

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
    # loop over batches
    for i, data in enumerate(data_loader):
        # retrieve inputs and labels for this batch
        x_batch, y_batch = data
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward pass -- calculate model output
        pred = model(x_batch)
        # compute the loss
        loss = loss_function(pred, y_batch)
        # backward pass
        loss.backward()
        # SGD update
        optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_val = model(x_val)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_val_class = torch.max(pred_val.data, 1)
    errors_train[epoch] = 100 - 100 * (
        predicted_train_class == y_train
    ).float().sum() / len(y_train)
    errors_val[epoch] = 100 - 100 * (predicted_val_class == y_val).float().sum() / len(
        y_val
    )
    losses_train[epoch] = loss_function(pred_train, y_train).item()
    losses_val[epoch] = loss_function(pred_val, y_val).item()
    print(
        f"Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}"
    )

    # tell scheduler to consider updating learning rate
    scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.688934, train error 61.75,  val loss 1.794534, percent error 63.50
# Epoch     1, train loss 1.140609, train error 43.20,  val loss 1.295282, percent error 51.90
# Epoch     2, train loss 1.002465, train error 38.08,  val loss 1.167053, percent error 45.70
# Epoch     3, train loss 0.939371, train error 34.78,  val loss 1.166934, percent error 42.90
# Epoch     4, train loss 0.851255, train error 32.47,  val loss 1.155369, percent error 41.60
# Epoch     5, train loss 0.757827, train error 27.55,  val loss 1.188199, percent error 42.90
# Epoch     6, train loss 0.710656, train error 26.60,  val loss 1.128512, percent error 41.50
# Epoch     7, train loss 0.620952, train error 24.00,  val loss 1.202540, percent error 42.20
# Epoch     8, train loss 0.560538, train error 21.82,  val loss 1.174763, percent error 39.30
# Epoch     9, train loss 0.531757, train error 19.82,  val loss 1.172948, percent error 38.60
# Epoch    10, train loss 0.482196, train error 18.18,  val loss 1.204975, percent error 38.00
# Epoch    11, train loss 0.427962, train error 15.72,  val loss 1.205678, percent error 38.60
# Epoch    12, train loss 0.386757, train error 14.28,  val loss 1.231448, percent error 37.70
# Epoch    13, train loss 0.430085, train error 15.28,  val loss 1.396406, percent error 39.60
# Epoch    14, train loss 0.420442, train error 14.78,  val loss 1.424261, percent error 37.20
# Epoch    15, train loss 0.535810, train error 17.80,  val loss 1.645041, percent error 40.40
# Epoch    16, train loss 0.404284, train error 14.57,  val loss 1.489339, percent error 37.00
# Epoch    17, train loss 0.320153, train error 11.80,  val loss 1.584909, percent error 38.40
# Epoch    18, train loss 0.271381, train error 10.32,  val loss 1.474045, percent error 34.80
# Epoch    19, train loss 0.261370, train error 8.82,  val loss 1.515008, percent error 37.30
# Epoch    20, train loss 0.074108, train error 1.75,  val loss 1.383063, percent error 32.40
# Epoch    21, train loss 0.031740, train error 0.25,  val loss 1.352518, percent error 33.00
# Epoch    22, train loss 0.020095, train error 0.05,  val loss 1.373872, percent error 32.70
# Epoch    23, train loss 0.014065, train error 0.00,  val loss 1.398755, percent error 33.00
# Epoch    24, train loss 0.011057, train error 0.00,  val loss 1.433998, percent error 33.10
# Epoch    25, train loss 0.009519, train error 0.00,  val loss 1.458460, percent error 32.90
# Epoch    26, train loss 0.008288, train error 0.00,  val loss 1.486192, percent error 33.10
# Epoch    27, train loss 0.007399, train error 0.00,  val loss 1.504837, percent error 33.00
# Epoch    28, train loss 0.006636, train error 0.00,  val loss 1.525638, percent error 33.00
# Epoch    29, train loss 0.006070, train error 0.00,  val loss 1.541756, percent error 33.20
# Epoch    30, train loss 0.005557, train error 0.00,  val loss 1.560745, percent error 32.80
# Epoch    31, train loss 0.005139, train error 0.00,  val loss 1.573671, percent error 32.90
# Epoch    32, train loss 0.004785, train error 0.00,  val loss 1.588274, percent error 32.50
# Epoch    33, train loss 0.004456, train error 0.00,  val loss 1.604315, percent error 33.20
# Epoch    34, train loss 0.004181, train error 0.00,  val loss 1.616163, percent error 32.90
# Epoch    35, train loss 0.003939, train error 0.00,  val loss 1.629089, percent error 32.80
# Epoch    36, train loss 0.003721, train error 0.00,  val loss 1.639932, percent error 32.90
# Epoch    37, train loss 0.003531, train error 0.00,  val loss 1.652279, percent error 32.80
# Epoch    38, train loss 0.003350, train error 0.00,  val loss 1.662548, percent error 33.10
# Epoch    39, train loss 0.003193, train error 0.00,  val loss 1.674459, percent error 33.00
# Epoch    40, train loss 0.003115, train error 0.00,  val loss 1.678183, percent error 33.00
# Epoch    41, train loss 0.003044, train error 0.00,  val loss 1.683188, percent error 33.10
# Epoch    42, train loss 0.002976, train error 0.00,  val loss 1.689252, percent error 33.00
# Epoch    43, train loss 0.002912, train error 0.00,  val loss 1.693456, percent error 33.00
# Epoch    44, train loss 0.002850, train error 0.00,  val loss 1.698056, percent error 33.00
# Epoch    45, train loss 0.002792, train error 0.00,  val loss 1.703100, percent error 33.00
# Epoch    46, train loss 0.002735, train error 0.00,  val loss 1.706963, percent error 32.90
# Epoch    47, train loss 0.002681, train error 0.00,  val loss 1.711097, percent error 33.00
# Epoch    48, train loss 0.002630, train error 0.00,  val loss 1.715443, percent error 33.10
# Epoch    49, train loss 0.002578, train error 0.00,  val loss 1.720675, percent error 32.90
# Epoch    50, train loss 0.002529, train error 0.00,  val loss 1.723800, percent error 33.00
# Epoch    51, train loss 0.002482, train error 0.00,  val loss 1.727500, percent error 33.00
# Epoch    52, train loss 0.002437, train error 0.00,  val loss 1.732792, percent error 33.10
# Epoch    53, train loss 0.002392, train error 0.00,  val loss 1.735702, percent error 33.00
# Epoch    54, train loss 0.002351, train error 0.00,  val loss 1.739190, percent error 33.00
# Epoch    55, train loss 0.002309, train error 0.00,  val loss 1.743920, percent error 33.00
# Epoch    56, train loss 0.002271, train error 0.00,  val loss 1.747351, percent error 33.00
# Epoch    57, train loss 0.002233, train error 0.00,  val loss 1.751260, percent error 33.00
# Epoch    58, train loss 0.002195, train error 0.00,  val loss 1.754953, percent error 33.10
# Epoch    59, train loss 0.002159, train error 0.00,  val loss 1.758727, percent error 33.00
# Epoch    60, train loss 0.002141, train error 0.00,  val loss 1.760824, percent error 33.00
# Epoch    61, train loss 0.002124, train error 0.00,  val loss 1.762442, percent error 33.00
# Epoch    62, train loss 0.002107, train error 0.00,  val loss 1.764288, percent error 33.00
# Epoch    63, train loss 0.002091, train error 0.00,  val loss 1.765883, percent error 33.00
# Epoch    64, train loss 0.002074, train error 0.00,  val loss 1.767586, percent error 33.00
# Epoch    65, train loss 0.002058, train error 0.00,  val loss 1.769236, percent error 33.00
# Epoch    66, train loss 0.002042, train error 0.00,  val loss 1.771153, percent error 33.00
# Epoch    67, train loss 0.002027, train error 0.00,  val loss 1.772848, percent error 33.00
# Epoch    68, train loss 0.002011, train error 0.00,  val loss 1.774607, percent error 33.00
# Epoch    69, train loss 0.001996, train error 0.00,  val loss 1.776085, percent error 33.00
# Epoch    70, train loss 0.001981, train error 0.00,  val loss 1.778050, percent error 33.00
# Epoch    71, train loss 0.001966, train error 0.00,  val loss 1.779698, percent error 33.00
# Epoch    72, train loss 0.001952, train error 0.00,  val loss 1.781475, percent error 33.00
# Epoch    73, train loss 0.001937, train error 0.00,  val loss 1.782722, percent error 33.00
# Epoch    74, train loss 0.001923, train error 0.00,  val loss 1.784697, percent error 33.00
# Epoch    75, train loss 0.001909, train error 0.00,  val loss 1.786229, percent error 33.00
# Epoch    76, train loss 0.001895, train error 0.00,  val loss 1.787896, percent error 33.00
# Epoch    77, train loss 0.001882, train error 0.00,  val loss 1.789497, percent error 33.00
# Epoch    78, train loss 0.001868, train error 0.00,  val loss 1.791196, percent error 33.00
# Epoch    79, train loss 0.001855, train error 0.00,  val loss 1.792700, percent error 33.00
# Epoch    80, train loss 0.001848, train error 0.00,  val loss 1.793684, percent error 32.90
# Epoch    81, train loss 0.001842, train error 0.00,  val loss 1.794466, percent error 33.00
# Epoch    82, train loss 0.001835, train error 0.00,  val loss 1.795326, percent error 32.90
# Epoch    83, train loss 0.001829, train error 0.00,  val loss 1.796000, percent error 32.90
# Epoch    84, train loss 0.001823, train error 0.00,  val loss 1.796757, percent error 32.90
# Epoch    85, train loss 0.001816, train error 0.00,  val loss 1.797723, percent error 33.00
# Epoch    86, train loss 0.001810, train error 0.00,  val loss 1.798433, percent error 32.90
# Epoch    87, train loss 0.001804, train error 0.00,  val loss 1.799136, percent error 33.00
# Epoch    88, train loss 0.001798, train error 0.00,  val loss 1.799921, percent error 32.90
# Epoch    89, train loss 0.001792, train error 0.00,  val loss 1.800671, percent error 33.00
# Epoch    90, train loss 0.001785, train error 0.00,  val loss 1.801473, percent error 33.00
# Epoch    91, train loss 0.001779, train error 0.00,  val loss 1.802293, percent error 33.00
# Epoch    92, train loss 0.001773, train error 0.00,  val loss 1.803061, percent error 33.00
# Epoch    93, train loss 0.001767, train error 0.00,  val loss 1.803808, percent error 33.00
# Epoch    94, train loss 0.001761, train error 0.00,  val loss 1.804576, percent error 33.00
# Epoch    95, train loss 0.001755, train error 0.00,  val loss 1.805352, percent error 33.00
# Epoch    96, train loss 0.001750, train error 0.00,  val loss 1.806172, percent error 33.00
# Epoch    97, train loss 0.001744, train error 0.00,  val loss 1.806934, percent error 33.00
# Epoch    98, train loss 0.001738, train error 0.00,  val loss 1.807770, percent error 33.00
# Epoch    99, train loss 0.001732, train error 0.00,  val loss 1.808484, percent error 33.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train, "r-", label="train")
ax.plot(errors_val, "b-", label="test")
ax.set_ylim(0, 100)
ax.set_xlim(0, n_epoch)
ax.set_xlabel("Epoch")
ax.set_ylabel("Error")
ax.set_title("TrainError %3.2f, Val Error %3.2f" % (errors_train[-1], errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
