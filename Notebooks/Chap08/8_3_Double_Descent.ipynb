# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random

random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
print("Using:", DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale = 2e-2
data = mnist1d.data.get_dataset(
    args, path="./mnist1d_data.pkl", download=False, regenerate=True
)

# Add 15% noise to training labels
for c_y in range(len(data["y"])):
    random_number = random.random()
    if random_number < 0.15:
        random_int = int(random.random() * 10)
        data["y"][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data["y"])))
print("Examples in test set: {}".format(len(data["y_test"])))
print("Dimensionality of each example: {}".format(data["x"].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)


# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

    D_i = 40  # Input dimensions
    D_k = n_hidden  # Hidden dimensions
    D_o = 10  # Output dimensions

    # Define a model with two hidden layers
    # And ReLU activations between them
    model = nn.Sequential(
        nn.Linear(D_i, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_o),
    )

    # Call the function you just defined
    model.apply(weights_init)

    # Return the model
    return model

# %%
def fit_model(model, data, n_epoch):

    # choose cross entropy loss function (equation 5.24)
    loss_function = torch.nn.CrossEntropyLoss()
    # construct SGD optimizer and initialize learning rate and momentum
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    x_train = torch.tensor(data["x"].astype("float32"))
    y_train = torch.tensor(data["y"].transpose().astype("long"))
    x_test = torch.tensor(data["x_test"].astype("float32"))
    y_test = torch.tensor(data["y_test"].astype("long"))

    # load the data into a class that creates the batches
    data_loader = DataLoader(
        TensorDataset(x_train, y_train),
        batch_size=100,
        shuffle=True,
        worker_init_fn=np.random.seed(1),
    )

    for epoch in range(n_epoch):
        # loop over batches
        for i, batch in enumerate(data_loader):
            # retrieve inputs and labels for this batch
            x_batch, y_batch = batch
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward pass -- calculate model output
            pred = model(x_batch)
            # compute the loss
            loss = loss_function(pred, y_batch)
            # backward pass
            loss.backward()
            # SGD update
            optimizer.step()

        # Run whole dataset to get statistics -- normally wouldn't do this
        pred_train = model(x_train)
        pred_test = model(x_test)
        _, predicted_train_class = torch.max(pred_train.data, 1)
        _, predicted_test_class = torch.max(pred_test.data, 1)
        errors_train = 100 - 100 * (
            predicted_train_class == y_train
        ).float().sum() / len(y_train)
        errors_test = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(
            y_test
        )
        losses_train = loss_function(pred_train, y_train).item()
        losses_test = loss_function(pred_test, y_test).item()
        if epoch % 100 == 0:
            print(
                f"Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}"
            )

    return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array(
    [
        2,
        4,
        6,
        8,
        10,
        14,
        18,
        22,
        26,
        30,
        35,
        40,
        45,
        50,
        55,
        60,
        70,
        80,
        90,
        100,
        120,
        140,
        160,
        180,
        200,
        250,
        300,
        400,
    ]
)

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f"Training model with {hidden_variables[c_hidden]:3d} hidden variables")
    # Get a model
    model = get_model(hidden_variables[c_hidden])
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden] = errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302976, train error 90.07,  test loss 2.302532, test error 89.75
# Epoch   100, train loss 1.939275, train error 73.25,  test loss 1.811390, test error 71.25
# Epoch   200, train loss 1.910962, train error 72.12,  test loss 1.750690, test error 70.70
# Epoch   300, train loss 1.903615, train error 71.60,  test loss 1.744235, test error 69.50
# Epoch   400, train loss 1.903166, train error 70.28,  test loss 1.744742, test error 69.65
# Epoch   500, train loss 1.902867, train error 70.90,  test loss 1.733158, test error 69.57
# Epoch   600, train loss 1.901865, train error 70.75,  test loss 1.739193, test error 69.97
# Epoch   700, train loss 1.902467, train error 71.15,  test loss 1.734334, test error 69.90
# Epoch   800, train loss 1.904620, train error 71.47,  test loss 1.733402, test error 70.22
# Epoch   900, train loss 1.904449, train error 70.20,  test loss 1.747820, test error 69.25
# Training model with   4 hidden variables
# Epoch     0, train loss 2.256898, train error 85.32,  test loss 2.246199, test error 84.78
# Epoch   100, train loss 1.818079, train error 67.80,  test loss 1.666426, test error 65.43
# Epoch   200, train loss 1.782607, train error 65.65,  test loss 1.617733, test error 62.58
# Epoch   300, train loss 1.768955, train error 65.60,  test loss 1.608324, test error 62.75
# Epoch   400, train loss 1.746948, train error 65.78,  test loss 1.598031, test error 62.88
# Epoch   500, train loss 1.745529, train error 64.88,  test loss 1.607126, test error 63.05
# Epoch   600, train loss 1.743732, train error 65.22,  test loss 1.605024, test error 62.92
# Epoch   700, train loss 1.748593, train error 65.38,  test loss 1.615683, test error 62.70
# Epoch   800, train loss 1.743348, train error 65.28,  test loss 1.607847, test error 62.85
# Epoch   900, train loss 1.740108, train error 64.95,  test loss 1.608289, test error 63.20
# Training model with   6 hidden variables
# Epoch     0, train loss 2.297305, train error 85.70,  test loss 2.304312, test error 85.43
# Epoch   100, train loss 1.665040, train error 60.03,  test loss 1.476108, test error 55.92
# Epoch   200, train loss 1.632588, train error 58.92,  test loss 1.472342, test error 56.78
# Epoch   300, train loss 1.614454, train error 57.78,  test loss 1.458044, test error 56.90
# Epoch   400, train loss 1.598122, train error 57.00,  test loss 1.456267, test error 56.33
# Epoch   500, train loss 1.602580, train error 57.08,  test loss 1.458046, test error 55.60
# Epoch   600, train loss 1.595017, train error 57.42,  test loss 1.451609, test error 55.55
# Epoch   700, train loss 1.588575, train error 56.30,  test loss 1.452754, test error 55.55
# Epoch   800, train loss 1.594713, train error 56.83,  test loss 1.447787, test error 55.50
# Epoch   900, train loss 1.587943, train error 56.17,  test loss 1.439487, test error 55.12
# Training model with   8 hidden variables
# Epoch     0, train loss 2.199669, train error 83.68,  test loss 2.155724, test error 82.18
# Epoch   100, train loss 1.658211, train error 59.03,  test loss 1.497150, test error 57.70
# Epoch   200, train loss 1.613493, train error 57.17,  test loss 1.459238, test error 55.53
# Epoch   300, train loss 1.593276, train error 55.80,  test loss 1.454137, test error 56.10
# Epoch   400, train loss 1.588612, train error 55.78,  test loss 1.469297, test error 56.33
# Epoch   500, train loss 1.583579, train error 56.00,  test loss 1.459961, test error 56.47
# Epoch   600, train loss 1.569742, train error 55.10,  test loss 1.448656, test error 55.60
# Epoch   700, train loss 1.553700, train error 54.20,  test loss 1.442741, test error 54.70
# Epoch   800, train loss 1.556887, train error 53.88,  test loss 1.449646, test error 55.30
# Epoch   900, train loss 1.548077, train error 53.97,  test loss 1.443174, test error 54.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.282015, train error 85.72,  test loss 2.284814, test error 86.70
# Epoch   100, train loss 1.597582, train error 56.42,  test loss 1.474133, test error 57.75
# Epoch   200, train loss 1.535183, train error 54.00,  test loss 1.464730, test error 56.65
# Epoch   300, train loss 1.508157, train error 53.10,  test loss 1.474151, test error 55.60
# Epoch   400, train loss 1.492096, train error 52.85,  test loss 1.491723, test error 56.40
# Epoch   500, train loss 1.482376, train error 52.60,  test loss 1.510716, test error 56.20
# Epoch   600, train loss 1.477398, train error 52.85,  test loss 1.513438, test error 55.45
# Epoch   700, train loss 1.474162, train error 52.60,  test loss 1.528579, test error 56.03
# Epoch   800, train loss 1.468642, train error 52.80,  test loss 1.538302, test error 55.33
# Epoch   900, train loss 1.467270, train error 52.53,  test loss 1.548397, test error 56.00
# Training model with  14 hidden variables
# Epoch     0, train loss 2.198409, train error 82.20,  test loss 2.188904, test error 83.25
# Epoch   100, train loss 1.509230, train error 52.95,  test loss 1.439942, test error 56.15
# Epoch   200, train loss 1.411632, train error 48.80,  test loss 1.435305, test error 53.72
# Epoch   300, train loss 1.379238, train error 48.05,  test loss 1.467003, test error 54.47
# Epoch   400, train loss 1.352371, train error 45.47,  test loss 1.507489, test error 54.72
# Epoch   500, train loss 1.345790, train error 45.78,  test loss 1.521283, test error 55.08
# Epoch   600, train loss 1.329810, train error 45.53,  test loss 1.537896, test error 54.75
# Epoch   700, train loss 1.327363, train error 44.95,  test loss 1.548437, test error 54.60
# Epoch   800, train loss 1.324459, train error 45.47,  test loss 1.566226, test error 55.33
# Epoch   900, train loss 1.317604, train error 45.90,  test loss 1.564899, test error 55.10
# Training model with  18 hidden variables
# Epoch     0, train loss 2.185780, train error 80.95,  test loss 2.160431, test error 81.40
# Epoch   100, train loss 1.381310, train error 46.72,  test loss 1.337677, test error 50.10
# Epoch   200, train loss 1.261759, train error 43.22,  test loss 1.336199, test error 49.55
# Epoch   300, train loss 1.226537, train error 42.00,  test loss 1.373393, test error 50.40
# Epoch   400, train loss 1.194380, train error 40.60,  test loss 1.396224, test error 49.75
# Epoch   500, train loss 1.167400, train error 39.58,  test loss 1.413080, test error 49.90
# Epoch   600, train loss 1.161193, train error 39.47,  test loss 1.450080, test error 50.38
# Epoch   700, train loss 1.154386, train error 39.03,  test loss 1.456635, test error 49.70
# Epoch   800, train loss 1.136221, train error 38.40,  test loss 1.475695, test error 49.58
# Epoch   900, train loss 1.130293, train error 38.42,  test loss 1.490959, test error 49.35
# Training model with  22 hidden variables
# Epoch     0, train loss 2.166973, train error 80.25,  test loss 2.130502, test error 79.50
# Epoch   100, train loss 1.303726, train error 43.60,  test loss 1.377162, test error 51.25
# Epoch   200, train loss 1.174909, train error 39.45,  test loss 1.440637, test error 52.12
# Epoch   300, train loss 1.098633, train error 37.95,  test loss 1.515450, test error 53.50
# Epoch   400, train loss 1.058547, train error 37.22,  test loss 1.599960, test error 53.85
# Epoch   500, train loss 1.040484, train error 35.70,  test loss 1.632473, test error 54.47
# Epoch   600, train loss 1.028425, train error 35.70,  test loss 1.679139, test error 54.70
# Epoch   700, train loss 1.020468, train error 35.53,  test loss 1.696685, test error 54.60
# Epoch   800, train loss 1.022667, train error 36.40,  test loss 1.761519, test error 54.67
# Epoch   900, train loss 1.007587, train error 35.07,  test loss 1.752054, test error 54.05
# Training model with  26 hidden variables
# Epoch     0, train loss 2.175398, train error 80.90,  test loss 2.134791, test error 79.32
# Epoch   100, train loss 1.136963, train error 37.72,  test loss 1.288792, test error 47.40
# Epoch   200, train loss 1.012328, train error 33.28,  test loss 1.416563, test error 48.72
# Epoch   300, train loss 0.937642, train error 31.30,  test loss 1.544274, test error 49.92
# Epoch   400, train loss 0.898324, train error 30.22,  test loss 1.664706, test error 51.45
# Epoch   500, train loss 0.871349, train error 29.60,  test loss 1.721702, test error 51.45
# Epoch   600, train loss 0.826171, train error 27.53,  test loss 1.794990, test error 51.22
# Epoch   700, train loss 0.813467, train error 26.85,  test loss 1.911995, test error 52.08
# Epoch   800, train loss 0.799471, train error 26.75,  test loss 2.022807, test error 53.33
# Epoch   900, train loss 0.779986, train error 25.70,  test loss 2.096554, test error 52.95
# Training model with  30 hidden variables
# Epoch     0, train loss 2.123398, train error 77.75,  test loss 2.074889, test error 77.78
# Epoch   100, train loss 1.139524, train error 36.30,  test loss 1.344729, test error 49.15
# Epoch   200, train loss 0.933093, train error 29.97,  test loss 1.519304, test error 50.97
# Epoch   300, train loss 0.839698, train error 27.50,  test loss 1.775715, test error 52.55
# Epoch   400, train loss 0.771162, train error 25.40,  test loss 1.999440, test error 52.97
# Epoch   500, train loss 0.720905, train error 24.32,  test loss 2.239036, test error 53.90
# Epoch   600, train loss 0.693717, train error 23.62,  test loss 2.449152, test error 54.75
# Epoch   700, train loss 0.686987, train error 22.82,  test loss 2.604273, test error 54.53
# Epoch   800, train loss 0.658262, train error 22.18,  test loss 2.713005, test error 55.53
# Epoch   900, train loss 0.664033, train error 22.40,  test loss 2.877729, test error 55.53
# Training model with  35 hidden variables
# Epoch     0, train loss 2.123175, train error 77.20,  test loss 2.099641, test error 79.22
# Epoch   100, train loss 0.982015, train error 32.82,  test loss 1.481087, test error 51.72
# Epoch   200, train loss 0.772750, train error 26.12,  test loss 1.831211, test error 53.38
# Epoch   300, train loss 0.652694, train error 21.43,  test loss 2.151306, test error 54.35
# Epoch   400, train loss 0.598109, train error 20.15,  test loss 2.473563, test error 55.08
# Epoch   500, train loss 0.540224, train error 16.93,  test loss 2.699195, test error 55.30
# Epoch   600, train loss 0.505508, train error 16.75,  test loss 2.958928, test error 55.20
# Epoch   700, train loss 0.479587, train error 16.10,  test loss 3.231165, test error 55.58
# Epoch   800, train loss 0.464533, train error 15.62,  test loss 3.475921, test error 56.05
# Epoch   900, train loss 0.455844, train error 15.25,  test loss 3.625846, test error 55.38
# Training model with  40 hidden variables
# Epoch     0, train loss 2.055197, train error 77.28,  test loss 2.004240, test error 77.28
# Epoch   100, train loss 0.926935, train error 29.62,  test loss 1.458824, test error 50.95
# Epoch   200, train loss 0.663859, train error 21.05,  test loss 1.968029, test error 52.25
# Epoch   300, train loss 0.526144, train error 17.82,  test loss 2.588410, test error 54.70
# Epoch   400, train loss 0.402808, train error 13.03,  test loss 3.180299, test error 55.30
# Epoch   500, train loss 0.375395, train error 12.50,  test loss 3.844686, test error 56.58
# Epoch   600, train loss 0.365540, train error 12.70,  test loss 4.513548, test error 57.00
# Epoch   700, train loss 0.294471, train error 10.10,  test loss 5.045604, test error 56.85
# Epoch   800, train loss 0.298074, train error 11.07,  test loss 5.599938, test error 56.83
# Epoch   900, train loss 0.250416, train error 8.80,  test loss 6.170586, test error 57.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.151782, train error 78.28,  test loss 2.114727, test error 77.68
# Epoch   100, train loss 0.803298, train error 26.20,  test loss 1.497384, test error 49.65
# Epoch   200, train loss 0.465636, train error 14.20,  test loss 2.307831, test error 53.65
# Epoch   300, train loss 0.322466, train error 10.30,  test loss 3.467791, test error 55.40
# Epoch   400, train loss 0.246855, train error 8.10,  test loss 4.747847, test error 56.05
# Epoch   500, train loss 0.158766, train error 4.93,  test loss 6.049345, test error 56.28
# Epoch   600, train loss 0.069309, train error 1.32,  test loss 7.386539, test error 56.12
# Epoch   700, train loss 0.012279, train error 0.00,  test loss 8.387004, test error 56.60
# Epoch   800, train loss 0.008355, train error 0.00,  test loss 9.045080, test error 56.50
# Epoch   900, train loss 0.006343, train error 0.00,  test loss 9.560488, test error 56.25
# Training model with  50 hidden variables
# Epoch     0, train loss 2.062720, train error 76.12,  test loss 2.032717, test error 76.95
# Epoch   100, train loss 0.713308, train error 22.30,  test loss 1.549514, test error 49.85
# Epoch   200, train loss 0.345786, train error 10.03,  test loss 2.539412, test error 52.33
# Epoch   300, train loss 0.152451, train error 3.50,  test loss 3.884337, test error 53.35
# Epoch   400, train loss 0.035550, train error 0.07,  test loss 5.351063, test error 52.80
# Epoch   500, train loss 0.014145, train error 0.00,  test loss 6.289272, test error 53.17
# Epoch   600, train loss 0.008701, train error 0.00,  test loss 6.911551, test error 53.28
# Epoch   700, train loss 0.006200, train error 0.00,  test loss 7.359987, test error 53.20
# Epoch   800, train loss 0.004713, train error 0.00,  test loss 7.716684, test error 53.33
# Epoch   900, train loss 0.003803, train error 0.00,  test loss 8.011638, test error 53.38
# Training model with  55 hidden variables
# Epoch     0, train loss 2.040521, train error 75.53,  test loss 1.982640, test error 76.10
# Epoch   100, train loss 0.644361, train error 19.85,  test loss 1.675053, test error 51.58
# Epoch   200, train loss 0.181184, train error 3.65,  test loss 3.036375, test error 53.03
# Epoch   300, train loss 0.033255, train error 0.00,  test loss 4.770986, test error 55.03
# Epoch   400, train loss 0.013160, train error 0.00,  test loss 5.735963, test error 54.83
# Epoch   500, train loss 0.007708, train error 0.00,  test loss 6.322548, test error 54.78
# Epoch   600, train loss 0.005322, train error 0.00,  test loss 6.752898, test error 55.08
# Epoch   700, train loss 0.004026, train error 0.00,  test loss 7.086041, test error 55.03
# Epoch   800, train loss 0.003186, train error 0.00,  test loss 7.346169, test error 55.12
# Epoch   900, train loss 0.002621, train error 0.00,  test loss 7.585676, test error 55.15
# Training model with  60 hidden variables
# Epoch     0, train loss 2.079206, train error 77.00,  test loss 2.040200, test error 76.43
# Epoch   100, train loss 0.546790, train error 15.53,  test loss 1.732950, test error 51.30
# Epoch   200, train loss 0.120936, train error 1.35,  test loss 3.377505, test error 55.38
# Epoch   300, train loss 0.022552, train error 0.00,  test loss 4.803245, test error 55.75
# Epoch   400, train loss 0.010347, train error 0.00,  test loss 5.540323, test error 55.65
# Epoch   500, train loss 0.006487, train error 0.00,  test loss 6.019107, test error 55.85
# Epoch   600, train loss 0.004610, train error 0.00,  test loss 6.374940, test error 56.03
# Epoch   700, train loss 0.003513, train error 0.00,  test loss 6.647854, test error 55.90
# Epoch   800, train loss 0.002810, train error 0.00,  test loss 6.882262, test error 55.95
# Epoch   900, train loss 0.002331, train error 0.00,  test loss 7.074796, test error 56.10
# Training model with  70 hidden variables
# Epoch     0, train loss 2.072000, train error 76.78,  test loss 2.030267, test error 75.78
# Epoch   100, train loss 0.349176, train error 8.60,  test loss 1.843627, test error 48.92
# Epoch   200, train loss 0.032031, train error 0.00,  test loss 3.410263, test error 51.85
# Epoch   300, train loss 0.010804, train error 0.00,  test loss 4.133853, test error 52.45
# Epoch   400, train loss 0.006022, train error 0.00,  test loss 4.542324, test error 52.55
# Epoch   500, train loss 0.004063, train error 0.00,  test loss 4.830625, test error 52.78
# Epoch   600, train loss 0.003002, train error 0.00,  test loss 5.042884, test error 52.72
# Epoch   700, train loss 0.002360, train error 0.00,  test loss 5.216418, test error 52.70
# Epoch   800, train loss 0.001929, train error 0.00,  test loss 5.366644, test error 52.70
# Epoch   900, train loss 0.001622, train error 0.00,  test loss 5.493375, test error 52.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.042318, train error 76.55,  test loss 1.987731, test error 75.85
# Epoch   100, train loss 0.243741, train error 4.50,  test loss 2.061709, test error 51.72
# Epoch   200, train loss 0.019892, train error 0.00,  test loss 3.442505, test error 52.53
# Epoch   300, train loss 0.008038, train error 0.00,  test loss 4.003165, test error 52.72
# Epoch   400, train loss 0.004752, train error 0.00,  test loss 4.340055, test error 52.78
# Epoch   500, train loss 0.003284, train error 0.00,  test loss 4.580950, test error 52.92
# Epoch   600, train loss 0.002470, train error 0.00,  test loss 4.765462, test error 52.90
# Epoch   700, train loss 0.001958, train error 0.00,  test loss 4.915845, test error 52.92
# Epoch   800, train loss 0.001613, train error 0.00,  test loss 5.043792, test error 52.85
# Epoch   900, train loss 0.001363, train error 0.00,  test loss 5.151439, test error 52.85
# Training model with  90 hidden variables
# Epoch     0, train loss 1.997696, train error 75.62,  test loss 1.932380, test error 75.43
# Epoch   100, train loss 0.144871, train error 1.55,  test loss 2.166207, test error 50.58
# Epoch   200, train loss 0.014993, train error 0.00,  test loss 3.225495, test error 51.45
# Epoch   300, train loss 0.006616, train error 0.00,  test loss 3.678818, test error 51.70
# Epoch   400, train loss 0.004062, train error 0.00,  test loss 3.948309, test error 51.78
# Epoch   500, train loss 0.002834, train error 0.00,  test loss 4.153027, test error 51.85
# Epoch   600, train loss 0.002151, train error 0.00,  test loss 4.304479, test error 51.58
# Epoch   700, train loss 0.001722, train error 0.00,  test loss 4.432974, test error 51.72
# Epoch   800, train loss 0.001424, train error 0.00,  test loss 4.540059, test error 51.62
# Epoch   900, train loss 0.001209, train error 0.00,  test loss 4.632208, test error 51.67
# Training model with 100 hidden variables
# Epoch     0, train loss 2.009311, train error 74.60,  test loss 1.982547, test error 75.55
# Epoch   100, train loss 0.082844, train error 0.15,  test loss 2.182794, test error 50.05
# Epoch   200, train loss 0.011840, train error 0.00,  test loss 2.976997, test error 50.67
# Epoch   300, train loss 0.005575, train error 0.00,  test loss 3.322087, test error 50.75
# Epoch   400, train loss 0.003503, train error 0.00,  test loss 3.535114, test error 50.50
# Epoch   500, train loss 0.002496, train error 0.00,  test loss 3.692958, test error 50.55
# Epoch   600, train loss 0.001914, train error 0.00,  test loss 3.818585, test error 50.83
# Epoch   700, train loss 0.001540, train error 0.00,  test loss 3.920796, test error 50.88
# Epoch   800, train loss 0.001281, train error 0.00,  test loss 4.007513, test error 50.83
# Epoch   900, train loss 0.001092, train error 0.00,  test loss 4.082686, test error 50.83
# Training model with 120 hidden variables
# Epoch     0, train loss 1.957483, train error 71.82,  test loss 1.893238, test error 73.25
# Epoch   100, train loss 0.049061, train error 0.00,  test loss 2.177695, test error 48.92
# Epoch   200, train loss 0.009303, train error 0.00,  test loss 2.770298, test error 49.50
# Epoch   300, train loss 0.004621, train error 0.00,  test loss 3.043046, test error 49.67
# Epoch   400, train loss 0.002953, train error 0.00,  test loss 3.217172, test error 49.78
# Epoch   500, train loss 0.002134, train error 0.00,  test loss 3.347875, test error 49.85
# Epoch   600, train loss 0.001651, train error 0.00,  test loss 3.450172, test error 49.85
# Epoch   700, train loss 0.001335, train error 0.00,  test loss 3.534799, test error 49.88
# Epoch   800, train loss 0.001115, train error 0.00,  test loss 3.606586, test error 49.75
# Epoch   900, train loss 0.000954, train error 0.00,  test loss 3.668885, test error 49.75
# Training model with 140 hidden variables
# Epoch     0, train loss 1.937227, train error 72.00,  test loss 1.852997, test error 71.95
# Epoch   100, train loss 0.036594, train error 0.00,  test loss 2.148619, test error 49.22
# Epoch   200, train loss 0.008143, train error 0.00,  test loss 2.630527, test error 49.35
# Epoch   300, train loss 0.004160, train error 0.00,  test loss 2.863445, test error 49.28
# Epoch   400, train loss 0.002699, train error 0.00,  test loss 3.012656, test error 49.15
# Epoch   500, train loss 0.001962, train error 0.00,  test loss 3.126157, test error 49.12
# Epoch   600, train loss 0.001525, train error 0.00,  test loss 3.214267, test error 49.15
# Epoch   700, train loss 0.001238, train error 0.00,  test loss 3.289876, test error 49.25
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.352365, test error 49.30
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.408184, test error 49.35
# Training model with 160 hidden variables
# Epoch     0, train loss 1.941370, train error 71.88,  test loss 1.874010, test error 72.68
# Epoch   100, train loss 0.029014, train error 0.00,  test loss 2.130514, test error 50.05
# Epoch   200, train loss 0.007228, train error 0.00,  test loss 2.542374, test error 49.78
# Epoch   300, train loss 0.003817, train error 0.00,  test loss 2.745393, test error 49.97
# Epoch   400, train loss 0.002502, train error 0.00,  test loss 2.880903, test error 50.05
# Epoch   500, train loss 0.001830, train error 0.00,  test loss 2.982221, test error 50.08
# Epoch   600, train loss 0.001428, train error 0.00,  test loss 3.064000, test error 50.03
# Epoch   700, train loss 0.001163, train error 0.00,  test loss 3.130412, test error 49.92
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.188673, test error 49.92
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.239292, test error 49.92
# Training model with 180 hidden variables
# Epoch     0, train loss 1.939942, train error 71.80,  test loss 1.869319, test error 72.15
# Epoch   100, train loss 0.024649, train error 0.00,  test loss 2.087354, test error 48.78
# Epoch   200, train loss 0.006649, train error 0.00,  test loss 2.446731, test error 48.88
# Epoch   300, train loss 0.003544, train error 0.00,  test loss 2.626541, test error 48.80
# Epoch   400, train loss 0.002344, train error 0.00,  test loss 2.747051, test error 48.72
# Epoch   500, train loss 0.001724, train error 0.00,  test loss 2.837594, test error 48.58
# Epoch   600, train loss 0.001349, train error 0.00,  test loss 2.910716, test error 48.80
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 2.971315, test error 48.62
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 3.023169, test error 48.65
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.068671, test error 48.62
# Training model with 200 hidden variables
# Epoch     0, train loss 1.930010, train error 71.80,  test loss 1.860551, test error 72.25
# Epoch   100, train loss 0.021623, train error 0.00,  test loss 1.993030, test error 48.10
# Epoch   200, train loss 0.006152, train error 0.00,  test loss 2.306549, test error 47.60
# Epoch   300, train loss 0.003345, train error 0.00,  test loss 2.469029, test error 47.83
# Epoch   400, train loss 0.002228, train error 0.00,  test loss 2.578168, test error 47.72
# Epoch   500, train loss 0.001645, train error 0.00,  test loss 2.660951, test error 47.95
# Epoch   600, train loss 0.001292, train error 0.00,  test loss 2.727166, test error 47.97
# Epoch   700, train loss 0.001057, train error 0.00,  test loss 2.783001, test error 47.97
# Epoch   800, train loss 0.000890, train error 0.00,  test loss 2.830605, test error 48.05
# Epoch   900, train loss 0.000766, train error 0.00,  test loss 2.872337, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.903565, train error 70.38,  test loss 1.816166, test error 71.53
# Epoch   100, train loss 0.017408, train error 0.00,  test loss 1.910787, test error 46.88
# Epoch   200, train loss 0.005421, train error 0.00,  test loss 2.168223, test error 47.08
# Epoch   300, train loss 0.003010, train error 0.00,  test loss 2.305836, test error 46.97
# Epoch   400, train loss 0.002031, train error 0.00,  test loss 2.398560, test error 46.97
# Epoch   500, train loss 0.001511, train error 0.00,  test loss 2.469520, test error 46.97
# Epoch   600, train loss 0.001192, train error 0.00,  test loss 2.526373, test error 46.92
# Epoch   700, train loss 0.000978, train error 0.00,  test loss 2.573950, test error 46.95
# Epoch   800, train loss 0.000826, train error 0.00,  test loss 2.615566, test error 46.92
# Epoch   900, train loss 0.000712, train error 0.00,  test loss 2.651391, test error 46.92
# Training model with 300 hidden variables
# Epoch     0, train loss 1.858842, train error 67.07,  test loss 1.815266, test error 69.43
# Epoch   100, train loss 0.014469, train error 0.00,  test loss 1.904403, test error 46.88
# Epoch   200, train loss 0.004822, train error 0.00,  test loss 2.133441, test error 46.88
# Epoch   300, train loss 0.002735, train error 0.00,  test loss 2.257315, test error 46.78
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.343010, test error 46.80
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.408480, test error 46.70
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.461050, test error 46.62
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.505289, test error 46.62
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.543650, test error 46.72
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.576984, test error 46.72
# Training model with 400 hidden variables
# Epoch     0, train loss 1.833027, train error 64.85,  test loss 1.751682, test error 69.18
# Epoch   100, train loss 0.011579, train error 0.00,  test loss 1.781046, test error 45.28
# Epoch   200, train loss 0.004147, train error 0.00,  test loss 1.961313, test error 44.97
# Epoch   300, train loss 0.002401, train error 0.00,  test loss 2.060505, test error 44.80
# Epoch   400, train loss 0.001656, train error 0.00,  test loss 2.130848, test error 44.90
# Epoch   500, train loss 0.001248, train error 0.00,  test loss 2.183043, test error 44.88
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.226113, test error 44.90
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.262730, test error 44.95
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.294286, test error 45.00
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.321766, test error 44.90

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data["y"])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, "r-", label="train")
ax.plot(hidden_variables, errors_test_all, "b-", label="test")

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(
    x=hidden_variable_at_num_training_examples,
    color="g",
    linestyle="--",
    label="N(weights) = N(train)",
)

ax.set_ylim(0, 100)
ax.set_xlabel("No. hidden variables")
ax.set_ylabel("Error")
ax.legend()
plt.show()
