# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-25b6pomr
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-25b6pomr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting requests (from mnist1d==0.0.2.post16)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: matplotlib in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.8)
# Requirement already satisfied: scipy in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Collecting charset_normalizer<4,>=2 (from requests->mnist1d==0.0.2.post16)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->mnist1d==0.0.2.post16)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->mnist1d==0.0.2.post16)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->mnist1d==0.0.2.post16)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in /home/roman/pyprojects/ML/R&D/udlbook/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 2.6 MB/s eta 0:00:00 0:00:01
# Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 12.5 MB/s eta 0:00:00
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=9f9551f96db42fd93b55a836802ee7533abce4bac879b00a3559941160c78194
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ccw062dq/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests, mnist1d
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 idna-3.11 mnist1d-0.0.2.post16 requests-2.32.5 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    nn.init.zeros_(layer_in.bias)
    print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.538867, train error 60.22,  test loss 1.617494, test error 66.90
# Epoch     1, train loss 1.269577, train error 46.15,  test loss 1.404224, test error 55.70
# Epoch     2, train loss 1.138345, train error 42.50,  test loss 1.345459, test error 54.00
# Epoch     3, train loss 1.001498, train error 35.72,  test loss 1.260367, test error 51.10
# Epoch     4, train loss 0.927555, train error 33.95,  test loss 1.226237, test error 47.90
# Epoch     5, train loss 0.808111, train error 28.70,  test loss 1.192452, test error 47.10
# Epoch     6, train loss 0.742252, train error 26.70,  test loss 1.170332, test error 44.20
# Epoch     7, train loss 0.638597, train error 21.65,  test loss 1.117702, test error 41.80
# Epoch     8, train loss 0.579925, train error 18.80,  test loss 1.132507, test error 41.30
# Epoch     9, train loss 0.511537, train error 16.95,  test loss 1.105983, test error 40.80
# Epoch    10, train loss 0.412683, train error 12.30,  test loss 1.074456, test error 38.40
# Epoch    11, train loss 0.366226, train error 9.95,  test loss 1.065946, test error 37.40
# Epoch    12, train loss 0.336852, train error 8.28,  test loss 1.103825, test error 38.40
# Epoch    13, train loss 0.317185, train error 9.00,  test loss 1.127913, test error 40.00
# Epoch    14, train loss 0.285879, train error 6.95,  test loss 1.130188, test error 37.80
# Epoch    15, train loss 0.265271, train error 6.95,  test loss 1.132214, test error 36.80
# Epoch    16, train loss 0.257823, train error 6.70,  test loss 1.162614, test error 38.50
# Epoch    17, train loss 0.215698, train error 4.07,  test loss 1.176102, test error 37.80
# Epoch    18, train loss 0.198746, train error 4.15,  test loss 1.164632, test error 38.30
# Epoch    19, train loss 0.200147, train error 4.53,  test loss 1.251550, test error 37.60
# Epoch    20, train loss 0.156156, train error 1.80,  test loss 1.182344, test error 37.80
# Epoch    21, train loss 0.144867, train error 1.35,  test loss 1.190515, test error 37.80
# Epoch    22, train loss 0.136091, train error 1.03,  test loss 1.210534, test error 38.30
# Epoch    23, train loss 0.130945, train error 1.28,  test loss 1.214037, test error 36.90
# Epoch    24, train loss 0.121319, train error 0.68,  test loss 1.230673, test error 37.10
# Epoch    25, train loss 0.116903, train error 0.78,  test loss 1.235475, test error 37.50
# Epoch    26, train loss 0.111020, train error 0.57,  test loss 1.243256, test error 37.80
# Epoch    27, train loss 0.104536, train error 0.53,  test loss 1.263815, test error 38.70
# Epoch    28, train loss 0.102678, train error 0.45,  test loss 1.283484, test error 38.20
# Epoch    29, train loss 0.095180, train error 0.35,  test loss 1.288415, test error 38.10
# Epoch    30, train loss 0.090226, train error 0.22,  test loss 1.290666, test error 37.40
# Epoch    31, train loss 0.087507, train error 0.22,  test loss 1.294109, test error 37.70
# Epoch    32, train loss 0.085665, train error 0.20,  test loss 1.296645, test error 37.80
# Epoch    33, train loss 0.084011, train error 0.18,  test loss 1.315338, test error 38.50
# Epoch    34, train loss 0.081963, train error 0.15,  test loss 1.311393, test error 38.10
# Epoch    35, train loss 0.079701, train error 0.15,  test loss 1.317273, test error 38.10
# Epoch    36, train loss 0.078160, train error 0.12,  test loss 1.322738, test error 37.80
# Epoch    37, train loss 0.076229, train error 0.10,  test loss 1.329913, test error 38.30
# Epoch    38, train loss 0.074689, train error 0.10,  test loss 1.330779, test error 38.00
# Epoch    39, train loss 0.073510, train error 0.10,  test loss 1.342523, test error 38.00
# Epoch    40, train loss 0.071453, train error 0.10,  test loss 1.341461, test error 37.80
# Epoch    41, train loss 0.070776, train error 0.07,  test loss 1.343110, test error 38.20
# Epoch    42, train loss 0.070024, train error 0.10,  test loss 1.344925, test error 38.20
# Epoch    43, train loss 0.069103, train error 0.10,  test loss 1.349759, test error 37.80
# Epoch    44, train loss 0.068524, train error 0.07,  test loss 1.354118, test error 38.20
# Epoch    45, train loss 0.067634, train error 0.05,  test loss 1.351020, test error 38.60
# Epoch    46, train loss 0.066851, train error 0.07,  test loss 1.359076, test error 38.30
# Epoch    47, train loss 0.066388, train error 0.05,  test loss 1.356578, test error 38.10
# Epoch    48, train loss 0.065492, train error 0.05,  test loss 1.364767, test error 38.20
# Epoch    49, train loss 0.064771, train error 0.05,  test loss 1.366137, test error 38.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
